# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
summary_df = pd.read_csv('/Users/yuenc2/Desktop/ENCO/scripts/responses/sachs/sachs_summary.csv')

# %%
# Out:
# model
# config
# valid_rate
# avg_F1
# avg_shd
# acyclic_rate
# anonymize
# append_format_hint
# avg_FN
# avg_FP
# avg_TN
# avg_TP
# avg_accuracy
# avg_accuracy_sd
# avg_accuracy_se
# avg_ancestor_accuracy
# avg_ancestor_f1
# avg_ancestor_precision
# avg_ancestor_recall
# avg_f1
# avg_f1_sd
# avg_f1_se
# avg_orientation_FN
# avg_orientation_TP
# avg_orientation_accuracy
# avg_orientation_eval_pairs
# avg_precision
# avg_precision_sd
# avg_precision_se
# avg_recall
# avg_recall_sd
# avg_recall_se
# avg_shd_sd
# avg_shd_se
# avg_skeleton_accuracy
# avg_skeleton_f1
# avg_skeleton_precision
# avg_skeleton_recall
# avg_vstruct_f1
# avg_vstruct_precision
# avg_vstruct_recall
# causal_rules
# col_order
# context_exceeded_any
# context_exceeded_by_error_rows
# context_exceeded_by_tokens_rows
# context_window
# dataset
# evaluated
# format_ok_rows
# format_rate
# format_scored_rows
# give_steps
# given_edge_count
# given_edge_frac
# given_edges
# int_budget_gain_acyclic_rate
# int_budget_gain_avg_ancestor_f1
# int_budget_gain_avg_f1
# int_budget_gain_avg_orientation_accuracy
# int_budget_gain_avg_shd
# int_budget_gain_avg_skeleton_f1
# int_budget_gain_avg_vstruct_f1
# int_n
# is_names_only
# matrix_acyclic_rate
# matrix_avg_ancestor_f1
# matrix_avg_f1
# matrix_avg_orientation_accuracy
# matrix_avg_shd
# matrix_avg_skeleton_f1
# matrix_avg_vstruct_f1
# names_only_acyclic_rate
# names_only_avg_ancestor_f1
# names_only_avg_f1
# names_only_avg_orientation_accuracy
# names_only_avg_shd
# names_only_avg_skeleton_f1
# names_only_avg_vstruct_f1
# nhd_ratio_sd
# nhd_sd
# num_pred_edges
# num_pred_edges_sd
# num_pred_edges_se
# num_rows
# obs_n
# parsed_model
# prompt_style
# prompt_tokens_missing_rows
# prompt_tokens_rows
# reasoning_guidance
# response_csv
# row_order
# shuffles_per_graph
# spread_n
# true_num_edges
# valid_rows
# wrapper_mode

# %%
col_to_drop = [col for col in summary_df.columns if 'ci95' in col] + [col for col in summary_df.columns if 'iqr' in col] + [col for col in summary_df.columns if 'var' in col] + [col for col in summary_df.columns if 'var' in col] + [col for col in summary_df.columns if 'min' in col] + [col for col in summary_df.columns if 'max' in col] + [col for col in summary_df.columns if 'consensus' in col] + [col for col in summary_df.columns if 'summary' in col]+ [col for col in summary_df.columns if 'matrix' in col] + [col for col in summary_df.columns if 'brier' in col]  + [col for col in summary_df.columns if 'real' in col] + [col for col in summary_df.columns if 'names_only' in col] + [col for col in summary_df.columns if 'prev_' in col] + [col for col in summary_df.columns if 'num_rows_' in col]+ [col for col in summary_df.columns if 'obs_budget_' in col] + [col for col in summary_df.columns if 'give_edge' in col] + [col for col in summary_df.columns if 'int_budget_' in col] + [col for col in summary_df.columns if 'given' in col] + [col for col in summary_df.columns if 'causal_rules' in col]
summary_df.drop(columns=col_to_drop, inplace=True)

# %%
summary_df.columns
# print columns without abbreviations
for col in summary_df.columns:
    print(col)
# Out:
# model
# config
# valid_rate
# avg_F1
# avg_shd
# acyclic_rate
# anonymize
# append_format_hint
# avg_FN
# avg_FP
# avg_TN
# avg_TP
# avg_accuracy
# avg_accuracy_sd
# avg_accuracy_se
# avg_ancestor_accuracy
# avg_ancestor_f1
# avg_ancestor_precision
# avg_ancestor_recall
# avg_f1
# avg_f1_sd
# avg_f1_se
# avg_orientation_FN
# avg_orientation_TP
# avg_orientation_accuracy
# avg_orientation_eval_pairs
# avg_precision
# avg_precision_sd
# avg_precision_se
# avg_recall
# avg_recall_sd
# avg_recall_se
# avg_shd_sd
# avg_shd_se
# avg_skeleton_accuracy
# avg_skeleton_f1
# avg_skeleton_precision
# avg_skeleton_recall
# avg_vstruct_f1
# avg_vstruct_precision
# avg_vstruct_recall
# col_order
# context_exceeded_any
# context_exceeded_by_error_rows
# context_exceeded_by_tokens_rows
# context_window
# dataset
# evaluated
# format_ok_rows
# format_rate
# format_scored_rows
# give_steps
# int_n
# nhd_ratio_sd
# nhd_sd
# num_pred_edges
# num_pred_edges_sd
# num_pred_edges_se
# num_rows
# obs_n
# parsed_model
# prompt_style
# prompt_tokens_missing_rows
# prompt_tokens_rows
# reasoning_guidance
# response_csv
# row_order
# shuffles_per_graph
# spread_n
# true_num_edges
# valid_rows
# wrapper_mode
