# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
summary_df = pd.read_csv('/Users/yuenc2/Desktop/ENCO/scripts/responses/sachs/sachs_summary.csv')

# %%
col_to_drop = [col for col in summary_df.columns if 'ci95' in col] + [col for col in summary_df.columns if 'iqr' in col] + [col for col in summary_df.columns if 'var' in col] + [col for col in summary_df.columns if 'var' in col] + [col for col in summary_df.columns if 'min' in col] + [col for col in summary_df.columns if 'max' in col] + [col for col in summary_df.columns if 'consensus' in col] + [col for col in summary_df.columns if 'summary' in col]+ [col for col in summary_df.columns if 'matrix' in col] + [col for col in summary_df.columns if 'brier' in col]  + [col for col in summary_df.columns if 'real' in col] + [col for col in summary_df.columns if 'names_only' in col] + [col for col in summary_df.columns if 'prev_' in col] + [col for col in summary_df.columns if 'num_rows_' in col]+ [col for col in summary_df.columns if 'obs_budget_' in col] + [col for col in summary_df.columns if 'give_edge' in col] + [col for col in summary_df.columns if 'int_budget_' in col] + [col for col in summary_df.columns if 'given' in col] + [col for col in summary_df.columns if 'causal_rules' in col]
summary_df.drop(columns=col_to_drop, inplace=True)

# %%
summary_df.columns
# print columns without abbreviations
for col in summary_df.columns:
    print(col)
# Out:
# model
# config
# valid_rate
# avg_F1
# avg_shd
# acyclic_rate
# anonymize
# anonymized_acyclic_rate
# anonymized_avg_ancestor_f1
# anonymized_avg_f1
# anonymized_avg_orientation_accuracy
# anonymized_avg_shd
# anonymized_avg_skeleton_f1
# anonymized_avg_vstruct_f1
# anonymized_nhd_mean
# anonymized_nhd_ratio_mean
# append_format_hint
# avg_FN
# avg_FP
# avg_TN
# avg_TP
# avg_accuracy
# avg_accuracy_sd
# avg_accuracy_se
# avg_ancestor_accuracy
# avg_ancestor_f1
# avg_ancestor_precision
# avg_ancestor_recall
# avg_f1
# avg_f1_sd
# avg_f1_se
# avg_orientation_FN
# avg_orientation_TP
# avg_orientation_accuracy
# avg_orientation_eval_pairs
# avg_precision
# avg_precision_sd
# avg_precision_se
# avg_recall
# avg_recall_sd
# avg_recall_se
# avg_shd_sd
# avg_shd_se
# avg_skeleton_accuracy
# avg_skeleton_f1
# avg_skeleton_precision
# avg_skeleton_recall
# avg_vstruct_f1
# avg_vstruct_precision
# avg_vstruct_recall
# col_order
# context_exceeded_any
# context_exceeded_by_error_rows
# ...

# %%
import pandas as pd
df = pd.read_csv("/Users/yuenc2/Desktop/ENCO/experiments/out/prompt_config_top_configs.csv")

# %%
df_llm = df[~df['model'].str.contains('|'.join(['PC', 'ENCO','GES']))]

# %%
df_llm[(df_llm['criterion'] == 'top_valid_rate') & (df_llm['criterion_value'] <= 0)].groupby(['model', 'graph','obs_n','int_n','anonymize']).apply(
    lambda x: x[['reasoning_guidance', 'wrapper_mode', 'append_format_hint', 'col_order']].drop_duplicates()
)
# Out:
# /var/folders/h3/mg_n_0ls7kgb1369wvkmb_dh0000gq/T/ipykernel_81226/4175699755.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_llm[(df_llm['criterion'] == 'top_valid_rate') & (df_llm['criterion_value'] <= 0)].groupby(['model', 'graph','obs_n','int_n','anonymize']).apply(
#                                                         reasoning_guidance  \
# model              graph      obs_n int_n anonymize
# GPT-5 Mini         alarm      0     0     0         0               staged
#                    asia       200   3     1         7               staged
#                    cancer     200   3     1         138             staged
# ...

# %%
df['criterion'].unique()
# Out:
# array(['top_valid_rate', 'top_f1'], dtype=object)
